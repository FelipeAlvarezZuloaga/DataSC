# %% [markdown]
# # API Application Programming Interface

# %% [markdown]
# En este notebook vamos a ver cómo podemos hacer uso de una API para poder descargar datos
#
# Recordemos qué es una API

# %% [markdown]
# ![Alt text](https://miro.medium.com/v2/resize:fit:1400/1*7yAihbfGrMCzjUzIF2UitA.jpeg "API")

# %% [markdown]
# ![Alt text](https://imagenes.20minutos.es/files/image_990_556/uploads/imagenes/2023/08/03/nasa.jpeg "NASA")

# %% [markdown]
# ## ¿Cómo conectarse a una API?
#
# Para lograr esto, se requiere una llave que identifica al usuario que está interactuando con la API. Debido a esto, el primer paso es obtener una llave para poder hacer uso del servicio. (Usualmente son dos llaves : Publica y Privada/Secreta)
#
# Ve a https://api.nasa.gov/ y completa el formulario para obtener tu llave API gratuita.
#
# La llave suele proporcionarse de inmediato y se envía a tu correo electrónico.

# %%
import requests #Para realizar solicitudes HTTP a la API
from IPython.display import Image, display #Para mostrar imágenes dentro del notebook
import json #Para manejar la respuesta en formato JSON

# %%
api_key = 'TU_LLAVE_API_AQUÍ'  # Reemplaza con tu llave API

# %%
#APOD
api_url = 'https://api.nasa.gov/planetary/apod' #Para Astronomic Picture Of the Day

# Definir los parámetros de la solicitud para APOD
params = {
    'api_key': api_key,
    'date': '2023-04-25'  # Opcional: establece una fecha específica en formato AAAA-MM-DD
}

# Realizar la solicitud GET a la API 
response = requests.get(api_url, params=params)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    data = response.json()
    
    # Mostrar el título y la explicación
    print(f"Título: {data['title']}\n")
    print(f"Fecha: {data['date']}\n")
    print(f"Explicación: {data['explanation']}\n")
    
    # Mostrar la imagen si es de tipo 'image'
    if data['media_type'] == 'image':
        image_url = data['url']
        display(Image(url=image_url))
    else:
        print("El contenido multimedia no es una imagen.")
else:
    print(f"Error en la solicitud: {response.status_code}")
# Out:
# Título: Northern Lights over Southern Europe
#
# Fecha: 2023-04-25
#
# Explicación: Did you see an aurora over the past two nights? Many people who don't live in Earth's far north did.  Reports of aurora came in not only from northern locales in the USA as Alaska, but as far south as Texas and Arizona. A huge auroral oval extended over Europe and Asia, too. Pictured, an impressively red aurora was captured last night near the town of Cáceres in central Spain. Auroras were also reported in parts of southern Spain. The auroras resulted from a strong Coronal Mass Event (CME) that occurred on the Sun a few days ago. Particles from the CME crossed the inner Solar System before colliding with the Earth's magnetosphere.  From there, electrons and protons spiraled down the Earth's northern magnetic field lines and collided with oxygen and nitrogen in Earth's atmosphere, causing picturesque auroral glows. Our unusually active Sun may provide future opportunities to see the northern lights in southern skies.
# <img src="https://apod.nasa.gov/apod/image/2304/NlightsSeurope_Cordero_960.jpg"/>

# %%
# Definir la URL y los parámetros para la API de Mars Rover Photos
api_url_mars = 'https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos'

params_mars = {
    'api_key': api_key,
    'earth_date': '2023-04-25'  # Fecha específica
}

# Realizar la solicitud
response_mars = requests.get(api_url_mars, params=params_mars)

if response_mars.status_code == 200:
    data_mars = response_mars.json()
    photos = data_mars['photos']
    
    if photos:
        for photo in photos[:5]:  # Mostrar las primeras 5 fotos
            print(f"Foto ID: {photo['id']}, Cámara: {photo['camera']['full_name']}")
            display(Image(url=photo['img_src']))
    else:
        print("No hay fotos disponibles para esta fecha.")
else:
    print(f"Error en la solicitud: {response_mars.status_code}")
# Out:
# Foto ID: 1130675, Cámara: Front Hazard Avoidance Camera
# <img src="https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/fcam/FLB_735739748EDR_F1010522FHAZ00302M_.JPG"/>
# Foto ID: 1130676, Cámara: Front Hazard Avoidance Camera
# <img src="https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/fcam/FRB_735739748EDR_F1010522FHAZ00302M_.JPG"/>
# Foto ID: 1130677, Cámara: Front Hazard Avoidance Camera
# <img src="https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/fcam/FLB_735733320EDR_F1010324FHAZ00200M_.JPG"/>
# Foto ID: 1130678, Cámara: Front Hazard Avoidance Camera
# <img src="https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/fcam/FLB_735717011EDR_F1010324FHAZ00200M_.JPG"/>
# Foto ID: 1130679, Cámara: Front Hazard Avoidance Camera
# <img src="https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/fcam/FLB_735716713EDR_F1010324FHAZ00200M_.JPG"/>

# %%
data_mars
# Out:
# {'photos': [{'id': 1130675,
#    'sol': 3810,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/fcam/FLB_735739748EDR_F1010522FHAZ00302M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130676,
#    'sol': 3810,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/fcam/FRB_735739748EDR_F1010522FHAZ00302M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130677,
#    'sol': 3810,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/fcam/FLB_735733320EDR_F1010324FHAZ00200M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130678,
#    'sol': 3810,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/fcam/FLB_735717011EDR_F1010324FHAZ00200M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130679,
#    'sol': 3810,
#    'camera': {'id': 20,
#     'name': 'FHAZ',
#     'rover_id': 5,
#     'full_name': 'Front Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/fcam/FLB_735716713EDR_F1010324FHAZ00200M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130680,
#    'sol': 3810,
#    'camera': {'id': 21,
#     'name': 'RHAZ',
#     'rover_id': 5,
#     'full_name': 'Rear Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/rcam/RLB_735739878EDR_S1010522RHAZ00300M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130681,
#    'sol': 3810,
#    'camera': {'id': 21,
#     'name': 'RHAZ',
#     'rover_id': 5,
#     'full_name': 'Rear Hazard Avoidance Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/rcam/RRB_735739878EDR_S1010522RHAZ00300M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130888,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039790011600210C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130889,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039790001105074C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130890,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039780051600209C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130891,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039780041600208C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130892,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039780031600207C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130893,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039780021600206C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130894,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039780011600205C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130895,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039780001600204C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130896,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039770041600203C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130897,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039770031600202C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130898,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039770021600201C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130899,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039770011600200C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130900,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039770001600199C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130901,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039760041600198C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130902,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039760031600197C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130903,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039760021105071C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130904,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039760021600196C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130905,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039760011600195C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130906,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039760011105070C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130907,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039750021105068C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130908,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039750021600193C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130909,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039750011600192C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130910,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039750011105067C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130911,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039740081105065C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130912,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039740081600191C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130913,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039740071105064C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130914,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039740071600190C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130915,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039740061105063C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130916,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039740061600189C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130917,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039740051105062C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130918,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039740051600188C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130919,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039740041105061C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130920,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039740041600187C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130921,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039740031105060C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130922,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039740031600186C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130923,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039740021105059C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130924,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039740021600185C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130925,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039740011105058C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130926,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039740011600184C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130927,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039730051105056C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130928,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039730051600183C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130929,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039730041105055C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130930,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810ML1039730041600182C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130931,
#    'sol': 3810,
#    'camera': {'id': 22,
#     'name': 'MAST',
#     'rover_id': 5,
#     'full_name': 'Mast Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03810/mcam/3810MR1039730031105054C00_DXXX.jpg',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
# ...
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130827,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735736129EDR_D1010372TRAV01175M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130828,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735736056EDR_D1010366TRAV01175M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130829,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735735979EDR_D1010360TRAV01175M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130830,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735735903EDR_D1010354TRAV01175M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130831,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735735832EDR_D1010348TRAV01175M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130832,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735735759EDR_D1010342TRAV01175M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130833,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735735689EDR_D1010336TRAV01175M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130834,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735735634EDR_D1010330TRAV01175M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130835,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735735578EDR_D1010330TRAV01175M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130836,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735735453EDR_D1010324TRAV01175M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130837,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735720227EDR_M1010324NCAM00580M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1130838,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735705380EDR_M1010324NCAM00580M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1131153,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735705312EDR_S1010324NCAM00567M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1131154,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735705274EDR_S1010324NCAM00567M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1131155,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735705236EDR_S1010324NCAM00567M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}},
#   {'id': 1131156,
#    'sol': 3810,
#    'camera': {'id': 26,
#     'name': 'NAVCAM',
#     'rover_id': 5,
#     'full_name': 'Navigation Camera'},
#    'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03810/opgs/edr/ncam/NRB_735705198EDR_S1010324NCAM00567M_.JPG',
#    'earth_date': '2023-04-25',
#    'rover': {'id': 5,
#     'name': 'Curiosity',
#     'landing_date': '2012-08-06',
#     'launch_date': '2011-11-26',
#     'status': 'active',
#     'max_sol': 4102,
#     'max_date': '2024-02-19',
#     'total_photos': 695670,
#     'cameras': [{'name': 'FHAZ', 'full_name': 'Front Hazard Avoidance Camera'},
#      {'name': 'NAVCAM', 'full_name': 'Navigation Camera'},
#      {'name': 'MAST', 'full_name': 'Mast Camera'},
#      {'name': 'CHEMCAM', 'full_name': 'Chemistry and Camera Complex'},
#      {'name': 'MAHLI', 'full_name': 'Mars Hand Lens Imager'},
#      {'name': 'MARDI', 'full_name': 'Mars Descent Imager'},
#      {'name': 'RHAZ', 'full_name': 'Rear Hazard Avoidance Camera'}]}}]}

# %% [markdown]
# # Consideraciones
#
# Las API suelen tener un número máximo de solicitudes que puedes hacer por hora/minuto/día y están ligadas a la dirección MAC o IP de tu computadora. Evitar el abuso de requests y gestionar la cantidad de información que se pide a la API es fundamental al considerar una API como fuente de datos
